# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("mctopherlinks.csv")

# %%
df.head()
# Out:
#                          url_from  \
# 0  http://www.mctopherganesh.com/
# 1  http://www.mctopherganesh.com/
# 2  http://www.mctopherganesh.com/
# 3  http://www.mctopherganesh.com/
# 4  http://www.mctopherganesh.com/
#
#                                           url_to
# 0  http://www.mctopherganesh.com/accounts/login/
# 1                 http://www.mctopherganesh.com/
# 2         http://www.mctopherganesh.com/post/58/
# 3          http://www.mctopherganesh.com/post/2/
# 4          http://www.mctopherganesh.com/post/5/

# %%
df_null_fix_test = df.astype(object).where(pd.notnull(df),None)

# %%
df_null_fix_test
# Out:
#                           url_from  \
# 0   http://www.mctopherganesh.com/
# 1   http://www.mctopherganesh.com/
# 2   http://www.mctopherganesh.com/
# 3   http://www.mctopherganesh.com/
# 4   http://www.mctopherganesh.com/
# 5   http://www.mctopherganesh.com/
# 6   http://www.mctopherganesh.com/
# 7   http://www.mctopherganesh.com/
# 8   http://www.mctopherganesh.com/
# 9   http://www.mctopherganesh.com/
# 10  http://www.mctopherganesh.com/
# 11  http://www.mctopherganesh.com/
# 12  http://www.mctopherganesh.com/
# 13  http://www.mctopherganesh.com/
# 14  http://www.mctopherganesh.com/
# 15  http://www.mctopherganesh.com/
# 16  http://www.mctopherganesh.com/
# 17  http://www.mctopherganesh.com/
# 18  http://www.mctopherganesh.com/
# 19  http://www.mctopherganesh.com/
# 20  http://www.mctopherganesh.com/
# 21  http://www.mctopherganesh.com/
# 22  http://www.mctopherganesh.com/
# 23  http://www.mctopherganesh.com/
# 24  http://www.mctopherganesh.com/
# ...

# %%
post_links = df['url_to'][2:]

# %%
post_links
# Out:
# 2     http://www.mctopherganesh.com/post/58/
# 3      http://www.mctopherganesh.com/post/2/
# 4      http://www.mctopherganesh.com/post/5/
# 5      http://www.mctopherganesh.com/post/8/
# 6      http://www.mctopherganesh.com/post/9/
# 7     http://www.mctopherganesh.com/post/10/
# 8     http://www.mctopherganesh.com/post/11/
# 9     http://www.mctopherganesh.com/post/12/
# 10    http://www.mctopherganesh.com/post/13/
# 11    http://www.mctopherganesh.com/post/14/
# 12    http://www.mctopherganesh.com/post/15/
# 13    http://www.mctopherganesh.com/post/16/
# 14    http://www.mctopherganesh.com/post/17/
# 15    http://www.mctopherganesh.com/post/18/
# 16    http://www.mctopherganesh.com/post/19/
# 17    http://www.mctopherganesh.com/post/20/
# 18    http://www.mctopherganesh.com/post/21/
# 19    http://www.mctopherganesh.com/post/22/
# 20    http://www.mctopherganesh.com/post/23/
# 21    http://www.mctopherganesh.com/post/24/
# 22    http://www.mctopherganesh.com/post/25/
# ...
